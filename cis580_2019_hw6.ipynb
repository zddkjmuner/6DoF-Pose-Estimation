# %% [markdown]
# Run the next code block. There will be two separate authentications needed. The first will download all extra files from the CIS580 shared drive files. The second connects your google drive to save files to 'cis580-2019-hw6'

# %%
# bootstrap environment into place
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
drive_service = build('drive', 'v3')

import io
import os
from googleapiclient.http import MediaIoBaseDownload

def download_file(fn, file_id):
    request = drive_service.files().get_media(fileId=file_id)
    downloaded = io.BytesIO()
    downloader = MediaIoBaseDownload(downloaded, request)
    done = False
    while done is False:
        # _ is a placeholder for a progress object that we ignore.
        # (Our file is small, so we skip reporting progress.)
        _, done = downloader.next_chunk()
    
    downloaded.seek(0)

    folder = fn.split('/')
    if len(folder) > 1:
        os.makedirs(folder[0], exist_ok=True)

    with open(fn, 'wb') as f:
        f.write(downloaded.read())

id_to_fn = {
        '1PIhom4rR_a_vm-zCt_1rYKbz8sd43Gel': "data/images.npz",
        '1IOxsTUF-MgmDRp3-0jPMJ-qo8yLZFCez': "data/train_data.npz",
        '1ZPRZoiuQVwWm88dWB4kWTBTtSQKBaDxs': "data/valid_data.npz",
        '1rJgn9NHdnwToyIERWbS8g_gZu19wAkkd': "data/kpt.npy",
        '1noGbThisv1HOi87dG66AfgQzpIv0o1y6': "data/misc_data.npz",
        '1Jp94eNQyXlTBYhqFFksbwRRl9VOGLAYT': "utils/__init__.py",
        '1UCCx78ZFL-BxsIScl0YkaLSRjw6Umliu': "utils/pose_utils.py",
        '1lV3oSGB2ygBj0vF2zaj_FKVaExz4-loi': "utils/plotting.py",
        '1td00aFXojVptGMz1XRTuVWSdpAHYi4lt': "utils/train_options.py",
        '18NNIqvS5-GB9xGWJX0wjHeC_RaaoKnWz': "hourglass.py",
        '1mJS9HFhDoUR1XGxRNQm2e-j4WZQn7Zhl': "dataset.py",
           }

# download all files into the vm
for fid, fn in id_to_fn.items():
    download_file(fn, fid)

# mount the user's google drive into the system
from google.colab import drive
drive.mount('/content/gdrive')
# create folder to write data to
os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6', exist_ok=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# The next code block handles the external library imports.

# %%
from __future__ import division
from __future__ import print_function

import torch
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.utils import make_grid

from hourglass import hg

from dataset import Dataset
from dataset import RandomFlipLR, RandomRescaleBB, RandomRotation,\
                    CropAndPad, LocsToHeatmaps,\
                    ToTensor, Normalize, Denormalize
from utils import TrainOptions, PoseUtils

from tqdm import tqdm
from PIL import Image
import os
from time import time
import numpy as np

# %% [markdown]
# Step 1) The Trainer class contains two locations where you must implement the training step and the test step as specified in the accompanying PDF

# %%
class Trainer(object):

    def __init__(self, options):
        self.options = options
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        train_transform_list = []
        train_transform_list.append(RandomRescaleBB(0.8, 1.2))
        train_transform_list.append(RandomFlipLR())
        train_transform_list.append(RandomRotation(degrees=options.degrees))
        train_transform_list.append(CropAndPad(out_size=(options.crop_size, options.crop_size)))
        train_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        train_transform_list.append(ToTensor())
        train_transform_list.append(Normalize())
        test_transform_list = [CropAndPad(out_size=(options.crop_size, options.crop_size))]
        test_transform_list.append(LocsToHeatmaps(out_size=(options.heatmap_size, options.heatmap_size)))
        test_transform_list.append(ToTensor())
        test_transform_list.append(Normalize())
        self.train_ds = Dataset(is_train=True, transform=transforms.Compose(train_transform_list))
        self.test_ds = Dataset(is_train=False, transform=transforms.Compose(test_transform_list))

        self.model = hg(num_stacks=options.num_stacks, num_blocks=options.num_blocks, num_classes=options.num_classes).to(self.device)
        # define loss function and optimizer
        self.heatmap_loss = torch.nn.MSELoss().to(self.device) # for Global loss
        self.optimizer = torch.optim.RMSprop(self.model.parameters(),
                                             lr = options.lr)


        self.pose_utils = PoseUtils(detection_thresh=options.detection_thresh, dist_thresh=options.dist_thresh)

        self.train_data_loader = DataLoader(self.train_ds, batch_size=options.batch_size,
                                            num_workers=options.num_workers,
                                            pin_memory=True,
                                            shuffle=True)
        self.test_data_loader = DataLoader(self.test_ds, batch_size=options.test_batch_size,
                                           num_workers=options.num_workers,
                                           pin_memory=True,
                                           shuffle=True)

        self.summary_iters = []
        self.losses = []
        self.pcks = []

    def train(self):
        self.total_step_count = 0
        start_time = time()
        for epoch in range(1,self.options.num_epochs+1):
            elapsed_time = time() - start_time
            seconds_per_epoch = elapsed_time / epoch
            remaining_time = (self.options.num_epochs - epoch) * seconds_per_epoch

            print("Epoch %d/%d - Elapsed Time %f - Remaining Time %f" %
                    (epoch, self.options.num_epochs,
                        elapsed_time, remaining_time))

            for step, batch in enumerate(self.train_data_loader):
                self.model.train()
                batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                """
                ADD YOUR CODE FOR THE TRAINING STEP HERE
                You have to name the output of your neural network pred_heatmap_list
                This list contains the output heatmaps for each stack of the Stacked Hourglass model
                Since we are using only 1 stack in this homework, pred_heatmap_list will contain only 1 tensor
                """
                inputs=batch['image']
                labels=batch['keypoint_heatmaps']
                
                self.optimizer.zero_grad()
                
                pred_heatmap_list=self.model(inputs)
                
                loss=self.heatmap_loss(pred_heatmap_list[0],labels)
                loss.backward()
                self.optimizer.step()
                
                self.total_step_count += 1
                if self.total_step_count % self.options.summary_steps == 0:
                    self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='train')
                if self.total_step_count % self.options.test_steps == 0:
                    self.model.eval()
                    batch = next(iter(self.test_data_loader))
                    batch = {k: v.to(self.device) if isinstance(v, torch.Tensor) else v for k,v in batch.items()}
                    """
                    ADD YOUR CODE FOR THE TEST STEP HERE
                    What you have to do is to perform a forward pass and record the loss and the output
                    """
                    with torch.no_grad():
                      pred_heatmap_list = self.model(batch['image']) 
                      loss = self.heatmap_loss(pred_heatmap_list[0], batch['keypoint_heatmaps']) 
                      self.save_summaries(batch, pred_heatmap_list[-1].detach(), loss.detach(), mode='test') 
                    
                    """"self.save_summaries(batch, pred_heatmap_list[-1], loss, mode='test')"""

        checkpoint = {'model': self.model.state_dict()}
        torch.save(checkpoint, '/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')

    def save_summaries(self, batch, pred_heatmaps, loss, mode='train'):
        gt_heatmaps = batch['keypoint_heatmaps'].to(self.device)
        pck = self.pose_utils.pck(gt_heatmaps, pred_heatmaps)

        batch = Denormalize()(batch)
        images = batch['image']

        gt_image_keypoints, pred_image_keypoints = self.pose_utils.draw_keypoints_with_labels(images, gt_heatmaps, pred_heatmaps)

        gt_image_keypoints_grid = make_grid(gt_image_keypoints, pad_value=1, nrow=3)
        pred_image_keypoints_grid = make_grid(pred_image_keypoints, pad_value=1, nrow=3)

        pred_heatmaps_grid = make_grid(pred_heatmaps[0,:,:,:].unsqueeze(0).transpose(0,1), pad_value=1, nrow=5)
        pred_heatmaps_grid[pred_heatmaps_grid > 1] = 1
        pred_heatmaps_grid[pred_heatmaps_grid < 0] = 0

        self.losses.append(loss)
        self.pcks.append(pck)
        self.summary_iters.append(self.total_step_count)

        folder = '/content/gdrive/My Drive/cis580-2019-hw6/logs/%d' % self.total_step_count
        os.makedirs(folder, exist_ok=True)

        gt_ikg = Image.fromarray((gt_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_ikg = Image.fromarray((pred_image_keypoints_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))
        pred_hg = Image.fromarray((pred_heatmaps_grid.cpu().detach().numpy().transpose(1,2,0) * 255.).astype(np.uint8))

        gt_ikg.save(os.path.join(folder, mode + '_gt_image_keypoints.jpg'))
        pred_ikg.save(os.path.join(folder, mode + '_pred_image_keypoints.jpg'))
        pred_hg.save(os.path.join(folder, mode + '_pred_heatmaps.jpg'))

# %% [markdown]
# The next block will start the training process. Be sure to run the above block first every time you want to test changes to the code.

# %%
options = TrainOptions().parse_args(["--name=gascan",
                                     "--summary_steps=200",
                                     "--num_epochs=400",
                                     "--test_steps=1000"])
trainer = Trainer(options)
trainer.train()
# Out:
# Epoch 1/400 - Elapsed Time 0.000002 - Remaining Time 0.000856
# Epoch 2/400 - Elapsed Time 5.902633 - Remaining Time 1174.624052
# Epoch 3/400 - Elapsed Time 12.179509 - Remaining Time 1611.754983
# Epoch 4/400 - Elapsed Time 18.640215 - Remaining Time 1845.381277
# Epoch 5/400 - Elapsed Time 24.759644 - Remaining Time 1956.011841
# Epoch 6/400 - Elapsed Time 30.960134 - Remaining Time 2033.048786
# Epoch 7/400 - Elapsed Time 37.424476 - Remaining Time 2101.117018
# Epoch 8/400 - Elapsed Time 43.357438 - Remaining Time 2124.514478
# Epoch 9/400 - Elapsed Time 49.772103 - Remaining Time 2162.321377
# Epoch 10/400 - Elapsed Time 56.014951 - Remaining Time 2184.583089
# Epoch 11/400 - Elapsed Time 62.038203 - Remaining Time 2193.896460
# Epoch 12/400 - Elapsed Time 68.363668 - Remaining Time 2210.425280
# Epoch 13/400 - Elapsed Time 74.357542 - Remaining Time 2213.566828
# Epoch 14/400 - Elapsed Time 80.551793 - Remaining Time 2220.927997
# Epoch 15/400 - Elapsed Time 86.596843 - Remaining Time 2222.652298
# Epoch 16/400 - Elapsed Time 92.649069 - Remaining Time 2223.577658
# Epoch 17/400 - Elapsed Time 98.961029 - Remaining Time 2229.533778
# Epoch 18/400 - Elapsed Time 105.273065 - Remaining Time 2234.128371
# Epoch 19/400 - Elapsed Time 111.709183 - Remaining Time 2240.063085
# Epoch 20/400 - Elapsed Time 117.948798 - Remaining Time 2241.027161
# Epoch 21/400 - Elapsed Time 124.138245 - Remaining Time 2240.399753
# Epoch 22/400 - Elapsed Time 130.796658 - Remaining Time 2247.324393
# Epoch 23/400 - Elapsed Time 137.490748 - Remaining Time 2253.652702
# Epoch 24/400 - Elapsed Time 143.680366 - Remaining Time 2250.992394
# Epoch 25/400 - Elapsed Time 149.730980 - Remaining Time 2245.964699
# Epoch 26/400 - Elapsed Time 155.681385 - Remaining Time 2239.416850
# Epoch 27/400 - Elapsed Time 161.987739 - Remaining Time 2237.830611
# Epoch 28/400 - Elapsed Time 167.980725 - Remaining Time 2231.743915
# Epoch 29/400 - Elapsed Time 174.410989 - Remaining Time 2231.257825
# Epoch 30/400 - Elapsed Time 180.895869 - Remaining Time 2231.049048
# Epoch 31/400 - Elapsed Time 187.145157 - Remaining Time 2227.631058
# Epoch 32/400 - Elapsed Time 193.201168 - Remaining Time 2221.813427
# Epoch 33/400 - Elapsed Time 199.718192 - Remaining Time 2221.108379
# Epoch 34/400 - Elapsed Time 206.055090 - Remaining Time 2218.122441
# Epoch 35/400 - Elapsed Time 212.753017 - Remaining Time 2218.710031
# Epoch 36/400 - Elapsed Time 219.105177 - Remaining Time 2215.396794
# Epoch 37/400 - Elapsed Time 225.585723 - Remaining Time 2213.178852
# Epoch 38/400 - Elapsed Time 231.469811 - Remaining Time 2205.054513
# Epoch 39/400 - Elapsed Time 237.530301 - Remaining Time 2198.677913
# Epoch 40/400 - Elapsed Time 243.633446 - Remaining Time 2192.701010
# Epoch 41/400 - Elapsed Time 249.890931 - Remaining Time 2188.069368
# Epoch 42/400 - Elapsed Time 256.011713 - Remaining Time 2182.195076
# Epoch 43/400 - Elapsed Time 261.936182 - Remaining Time 2174.679469
# Epoch 44/400 - Elapsed Time 268.982220 - Remaining Time 2176.310687
# Epoch 45/400 - Elapsed Time 275.188002 - Remaining Time 2170.927570
# Epoch 46/400 - Elapsed Time 281.817343 - Remaining Time 2168.768252
# Epoch 47/400 - Elapsed Time 288.239409 - Remaining Time 2164.861946
# Epoch 48/400 - Elapsed Time 294.797637 - Remaining Time 2161.849334
# Epoch 49/400 - Elapsed Time 300.983617 - Remaining Time 2156.025498
# Epoch 50/400 - Elapsed Time 307.125585 - Remaining Time 2149.879096
# Epoch 51/400 - Elapsed Time 313.227610 - Remaining Time 2143.459525
# Epoch 52/400 - Elapsed Time 319.607906 - Remaining Time 2138.914450
# Epoch 53/400 - Elapsed Time 325.999537 - Remaining Time 2134.374330
# Epoch 54/400 - Elapsed Time 334.299783 - Remaining Time 2141.994903
# Epoch 55/400 - Elapsed Time 340.214263 - Remaining Time 2134.071289
# Epoch 56/400 - Elapsed Time 346.385240 - Remaining Time 2127.795045
# Epoch 57/400 - Elapsed Time 352.426968 - Remaining Time 2120.744738
# Epoch 58/400 - Elapsed Time 358.430434 - Remaining Time 2113.503591
# Epoch 59/400 - Elapsed Time 364.778178 - Remaining Time 2108.294215
# Epoch 60/400 - Elapsed Time 371.327312 - Remaining Time 2104.188100
# Epoch 61/400 - Elapsed Time 377.662766 - Remaining Time 2098.814385
# Epoch 62/400 - Elapsed Time 383.688955 - Remaining Time 2091.723656
# Epoch 63/400 - Elapsed Time 389.825999 - Remaining Time 2085.259707
# Epoch 64/400 - Elapsed Time 395.711125 - Remaining Time 2077.483404
# Epoch 65/400 - Elapsed Time 402.492446 - Remaining Time 2074.384143
# Epoch 66/400 - Elapsed Time 408.662761 - Remaining Time 2068.081245
# Epoch 67/400 - Elapsed Time 414.785727 - Remaining Time 2061.546973
# Epoch 68/400 - Elapsed Time 421.117532 - Remaining Time 2056.044419
# Epoch 69/400 - Elapsed Time 427.161302 - Remaining Time 2049.136102
# Epoch 70/400 - Elapsed Time 433.023209 - Remaining Time 2041.395130
# Epoch 71/400 - Elapsed Time 439.074253 - Remaining Time 2034.583511
# Epoch 72/400 - Elapsed Time 445.152512 - Remaining Time 2027.916997
# Epoch 73/400 - Elapsed Time 451.694286 - Remaining Time 2023.342896
# Epoch 74/400 - Elapsed Time 458.336452 - Remaining Time 2019.157883
# Epoch 75/400 - Elapsed Time 464.512578 - Remaining Time 2012.887837
# Epoch 76/400 - Elapsed Time 470.568906 - Remaining Time 2006.109548
# Epoch 77/400 - Elapsed Time 476.837628 - Remaining Time 2000.240959
# Epoch 78/400 - Elapsed Time 483.118671 - Remaining Time 1994.412975
# Epoch 79/400 - Elapsed Time 489.112186 - Remaining Time 1987.405210
# Epoch 80/400 - Elapsed Time 495.367082 - Remaining Time 1981.468328
# Epoch 81/400 - Elapsed Time 501.555323 - Remaining Time 1975.261087
# Epoch 82/400 - Elapsed Time 507.725167 - Remaining Time 1968.982964
# Epoch 83/400 - Elapsed Time 513.873949 - Remaining Time 1962.627011
# Epoch 84/400 - Elapsed Time 520.159462 - Remaining Time 1956.790356
# Epoch 85/400 - Elapsed Time 526.422271 - Remaining Time 1950.859004
# Epoch 86/400 - Elapsed Time 533.582082 - Remaining Time 1948.195045
# Epoch 87/400 - Elapsed Time 540.061289 - Remaining Time 1942.979121
# Epoch 88/400 - Elapsed Time 546.193143 - Remaining Time 1936.502960
# Epoch 89/400 - Elapsed Time 552.526126 - Remaining Time 1930.737361
# Epoch 90/400 - Elapsed Time 558.886037 - Remaining Time 1925.051906
# Epoch 91/400 - Elapsed Time 564.904837 - Remaining Time 1918.193349
# Epoch 92/400 - Elapsed Time 570.844653 - Remaining Time 1911.088622
# Epoch 93/400 - Elapsed Time 577.403276 - Remaining Time 1906.051676
# Epoch 94/400 - Elapsed Time 583.517755 - Remaining Time 1899.536522
# Epoch 95/400 - Elapsed Time 590.069483 - Remaining Time 1894.433603
# Epoch 96/400 - Elapsed Time 596.654199 - Remaining Time 1889.404963
# Epoch 97/400 - Elapsed Time 603.029915 - Remaining Time 1883.691383
# Epoch 98/400 - Elapsed Time 609.067607 - Remaining Time 1876.922625
# Epoch 99/400 - Elapsed Time 615.638222 - Remaining Time 1871.788938
# Epoch 100/400 - Elapsed Time 621.895281 - Remaining Time 1865.685844
# Epoch 101/400 - Elapsed Time 628.021007 - Remaining Time 1859.190901
# Epoch 102/400 - Elapsed Time 634.036787 - Remaining Time 1852.381984
# Epoch 103/400 - Elapsed Time 639.999062 - Remaining Time 1845.434188
# Epoch 104/400 - Elapsed Time 646.273758 - Remaining Time 1839.394541
# Epoch 105/400 - Elapsed Time 652.179008 - Remaining Time 1832.312452
# Epoch 106/400 - Elapsed Time 658.143307 - Remaining Time 1825.416341
# Epoch 107/400 - Elapsed Time 667.002445 - Remaining Time 1826.464640
# Epoch 108/400 - Elapsed Time 673.081802 - Remaining Time 1819.813762
# Epoch 109/400 - Elapsed Time 679.172850 - Remaining Time 1813.204580
# Epoch 110/400 - Elapsed Time 685.337376 - Remaining Time 1806.798537
# Epoch 111/400 - Elapsed Time 691.501827 - Remaining Time 1800.396650
# Epoch 112/400 - Elapsed Time 697.936300 - Remaining Time 1794.693342
# Epoch 113/400 - Elapsed Time 703.963615 - Remaining Time 1787.942988
# Epoch 114/400 - Elapsed Time 710.186622 - Remaining Time 1781.696263
# Epoch 115/400 - Elapsed Time 716.360317 - Remaining Time 1775.327742
# Epoch 116/400 - Elapsed Time 722.426345 - Remaining Time 1768.698982
# Epoch 117/400 - Elapsed Time 728.777818 - Remaining Time 1762.770279
# Epoch 118/400 - Elapsed Time 734.911182 - Remaining Time 1756.313164
# Epoch 119/400 - Elapsed Time 741.119118 - Remaining Time 1750.037582
# Epoch 120/400 - Elapsed Time 747.145032 - Remaining Time 1743.338408
# Epoch 121/400 - Elapsed Time 753.301234 - Remaining Time 1736.950779
# Epoch 122/400 - Elapsed Time 759.602376 - Remaining Time 1730.897216
# Epoch 123/400 - Elapsed Time 765.812082 - Remaining Time 1724.633713
# Epoch 124/400 - Elapsed Time 772.063598 - Remaining Time 1718.464138
# Epoch 125/400 - Elapsed Time 778.488677 - Remaining Time 1712.675089
# Epoch 126/400 - Elapsed Time 784.722006 - Remaining Time 1706.458966
# Epoch 127/400 - Elapsed Time 790.932919 - Remaining Time 1700.194384
# Epoch 128/400 - Elapsed Time 797.553009 - Remaining Time 1694.800144
# Epoch 129/400 - Elapsed Time 803.829858 - Remaining Time 1688.665826
# Epoch 130/400 - Elapsed Time 809.965956 - Remaining Time 1682.236985
# Epoch 131/400 - Elapsed Time 816.059862 - Remaining Time 1675.725975
# Epoch 132/400 - Elapsed Time 822.043124 - Remaining Time 1668.996645
# Epoch 133/400 - Elapsed Time 828.236186 - Remaining Time 1662.699711
# Epoch 134/400 - Elapsed Time 834.442135 - Remaining Time 1656.429910
# Epoch 135/400 - Elapsed Time 840.553111 - Remaining Time 1649.974626
# Epoch 136/400 - Elapsed Time 846.540964 - Remaining Time 1643.285401
# Epoch 137/400 - Elapsed Time 852.855718 - Remaining Time 1637.233970
# Epoch 138/400 - Elapsed Time 859.704884 - Remaining Time 1632.193330
# Epoch 139/400 - Elapsed Time 865.764845 - Remaining Time 1625.644781
# Epoch 140/400 - Elapsed Time 871.936738 - Remaining Time 1619.311086
# Epoch 141/400 - Elapsed Time 878.429719 - Remaining Time 1613.569484
# Epoch 142/400 - Elapsed Time 884.741799 - Remaining Time 1607.488621
# Epoch 143/400 - Elapsed Time 891.014288 - Remaining Time 1601.333371
# Epoch 144/400 - Elapsed Time 897.255083 - Remaining Time 1595.120147
# Epoch 145/400 - Elapsed Time 903.666815 - Remaining Time 1589.207157
# Epoch 146/400 - Elapsed Time 910.319122 - Remaining Time 1583.705869
# Epoch 147/400 - Elapsed Time 916.462942 - Remaining Time 1577.313771
# Epoch 148/400 - Elapsed Time 922.709343 - Remaining Time 1571.099693
# Epoch 149/400 - Elapsed Time 929.219988 - Remaining Time 1565.330316
# Epoch 150/400 - Elapsed Time 935.560238 - Remaining Time 1559.267063
# Epoch 151/400 - Elapsed Time 942.121130 - Remaining Time 1553.563983
# Epoch 152/400 - Elapsed Time 948.169758 - Remaining Time 1547.013815
# Epoch 153/400 - Elapsed Time 954.121503 - Remaining Time 1540.313800
# Epoch 154/400 - Elapsed Time 960.147029 - Remaining Time 1533.741358
# Epoch 155/400 - Elapsed Time 965.994915 - Remaining Time 1526.895188
# Epoch 156/400 - Elapsed Time 971.903016 - Remaining Time 1520.156000
# Epoch 157/400 - Elapsed Time 977.930094 - Remaining Time 1513.611548
# Epoch 158/400 - Elapsed Time 984.055261 - Remaining Time 1507.223881
# Epoch 159/400 - Elapsed Time 992.819560 - Remaining Time 1504.839710
# Epoch 160/400 - Elapsed Time 999.082489 - Remaining Time 1498.623734
# Epoch 161/400 - Elapsed Time 1004.995548 - Remaining Time 1491.887801
# Epoch 162/400 - Elapsed Time 1011.054058 - Remaining Time 1485.375715
# Epoch 163/400 - Elapsed Time 1017.527709 - Remaining Time 1479.472804
# Epoch 164/400 - Elapsed Time 1024.067548 - Remaining Time 1473.658178
# Epoch 165/400 - Elapsed Time 1030.136797 - Remaining Time 1467.164530
# Epoch 166/400 - Elapsed Time 1036.150411 - Remaining Time 1460.597567
# Epoch 167/400 - Elapsed Time 1042.316370 - Remaining Time 1454.249786
# Epoch 168/400 - Elapsed Time 1048.310983 - Remaining Time 1447.667548
# Epoch 169/400 - Elapsed Time 1054.359782 - Remaining Time 1441.166330
# Epoch 170/400 - Elapsed Time 1060.616350 - Remaining Time 1434.951532
# Epoch 171/400 - Elapsed Time 1066.671245 - Remaining Time 1428.466171
# Epoch 172/400 - Elapsed Time 1072.676632 - Remaining Time 1421.920187
# Epoch 173/400 - Elapsed Time 1078.878327 - Remaining Time 1415.638036
# Epoch 174/400 - Elapsed Time 1085.056285 - Remaining Time 1409.325979
# Epoch 175/400 - Elapsed Time 1091.119503 - Remaining Time 1402.867932
# Epoch 176/400 - Elapsed Time 1097.770530 - Remaining Time 1397.162493
# Epoch 177/400 - Elapsed Time 1104.134798 - Remaining Time 1391.085084
# Epoch 178/400 - Elapsed Time 1110.262589 - Remaining Time 1384.709522
# Epoch 179/400 - Elapsed Time 1116.163189 - Remaining Time 1378.056228
# Epoch 180/400 - Elapsed Time 1122.307522 - Remaining Time 1371.709194
# Epoch 181/400 - Elapsed Time 1128.425440 - Remaining Time 1365.332438
# Epoch 182/400 - Elapsed Time 1134.475584 - Remaining Time 1358.877348
# Epoch 183/400 - Elapsed Time 1140.521056 - Remaining Time 1352.421143
# Epoch 184/400 - Elapsed Time 1146.552703 - Remaining Time 1345.953173
# Epoch 185/400 - Elapsed Time 1152.503896 - Remaining Time 1339.396420
# Epoch 186/400 - Elapsed Time 1158.587145 - Remaining Time 1332.998113
# Epoch 187/400 - Elapsed Time 1164.714164 - Remaining Time 1326.653032
# Epoch 188/400 - Elapsed Time 1170.685185 - Remaining Time 1320.134358
# Epoch 189/400 - Elapsed Time 1177.070796 - Remaining Time 1314.084328
# Epoch 190/400 - Elapsed Time 1183.717828 - Remaining Time 1308.319705
# Epoch 191/400 - Elapsed Time 1190.148672 - Remaining Time 1302.309280
# Epoch 192/400 - Elapsed Time 1196.388812 - Remaining Time 1296.087880
# Epoch 193/400 - Elapsed Time 1202.343122 - Remaining Time 1289.559722
# Epoch 194/400 - Elapsed Time 1208.710126 - Remaining Time 1283.475701
# Epoch 195/400 - Elapsed Time 1215.243156 - Remaining Time 1277.563318
# Epoch 196/400 - Elapsed Time 1221.096580 - Remaining Time 1270.937257
# Epoch 197/400 - Elapsed Time 1227.024732 - Remaining Time 1264.396044
# Epoch 198/400 - Elapsed Time 1232.821173 - Remaining Time 1257.726652
# Epoch 199/400 - Elapsed Time 1238.740273 - Remaining Time 1251.189924
# Epoch 200/400 - Elapsed Time 1244.641505 - Remaining Time 1244.641505
# Epoch 201/400 - Elapsed Time 1250.663734 - Remaining Time 1238.219319
# Epoch 202/400 - Elapsed Time 1256.928744 - Remaining Time 1232.039066
# Epoch 203/400 - Elapsed Time 1263.574325 - Remaining Time 1226.227301
# Epoch 204/400 - Elapsed Time 1269.555443 - Remaining Time 1219.768955
# Epoch 205/400 - Elapsed Time 1275.444281 - Remaining Time 1213.227487
# Epoch 206/400 - Elapsed Time 1281.621979 - Remaining Time 1206.964388
# Epoch 207/400 - Elapsed Time 1287.925332 - Remaining Time 1200.819271
# Epoch 208/400 - Elapsed Time 1293.972283 - Remaining Time 1194.435953
# Epoch 209/400 - Elapsed Time 1300.204036 - Remaining Time 1188.224741
# Epoch 210/400 - Elapsed Time 1306.074055 - Remaining Time 1181.686050
# Epoch 211/400 - Elapsed Time 1312.108477 - Remaining Time 1175.300958
# Epoch 212/400 - Elapsed Time 1320.529568 - Remaining Time 1171.035655
# Epoch 213/400 - Elapsed Time 1326.559484 - Remaining Time 1164.632035
# Epoch 214/400 - Elapsed Time 1332.527659 - Remaining Time 1158.178245
# Epoch 215/400 - Elapsed Time 1338.908109 - Remaining Time 1152.083722
# Epoch 216/400 - Elapsed Time 1345.254411 - Remaining Time 1145.957461
# Epoch 217/400 - Elapsed Time 1351.418280 - Remaining Time 1139.675324
# Epoch 218/400 - Elapsed Time 1357.328825 - Remaining Time 1133.182780
# Epoch 219/400 - Elapsed Time 1363.260212 - Remaining Time 1126.712778
# Epoch 220/400 - Elapsed Time 1369.294672 - Remaining Time 1120.332005
# Epoch 221/400 - Elapsed Time 1375.320444 - Remaining Time 1113.947328
# Epoch 222/400 - Elapsed Time 1381.295473 - Remaining Time 1107.525199
# Epoch 223/400 - Elapsed Time 1387.824372 - Remaining Time 1101.546699
# Epoch 224/400 - Elapsed Time 1393.893479 - Remaining Time 1095.202019
# Epoch 225/400 - Elapsed Time 1399.793777 - Remaining Time 1088.728494
# Epoch 226/400 - Elapsed Time 1405.657592 - Remaining Time 1082.231952
# Epoch 227/400 - Elapsed Time 1411.720233 - Remaining Time 1075.892512
# Epoch 228/400 - Elapsed Time 1417.904230 - Remaining Time 1069.647051
# Epoch 229/400 - Elapsed Time 1424.505233 - Remaining Time 1063.713514
# Epoch 230/400 - Elapsed Time 1430.555194 - Remaining Time 1057.366883
# Epoch 231/400 - Elapsed Time 1436.527435 - Remaining Time 1050.965959
# Epoch 232/400 - Elapsed Time 1442.487105 - Remaining Time 1044.559628
# Epoch 233/400 - Elapsed Time 1448.707414 - Remaining Time 1038.343940
# Epoch 234/400 - Elapsed Time 1454.741232 - Remaining Time 1031.995917
# Epoch 235/400 - Elapsed Time 1460.763184 - Remaining Time 1025.642236
# Epoch 236/400 - Elapsed Time 1466.800947 - Remaining Time 1019.302353
# Epoch 237/400 - Elapsed Time 1472.922529 - Remaining Time 1013.022668
# Epoch 238/400 - Elapsed Time 1478.886827 - Remaining Time 1006.637252
# Epoch 239/400 - Elapsed Time 1484.722204 - Remaining Time 1000.168514
# Epoch 240/400 - Elapsed Time 1491.190513 - Remaining Time 994.127009
# Epoch 241/400 - Elapsed Time 1497.305520 - Remaining Time 987.848870
# Epoch 242/400 - Elapsed Time 1503.938766 - Remaining Time 981.910434
# Epoch 243/400 - Elapsed Time 1510.111583 - Remaining Time 975.668801
# Epoch 244/400 - Elapsed Time 1516.687248 - Remaining Time 969.685290
# Epoch 245/400 - Elapsed Time 1523.313078 - Remaining Time 963.728682
# Epoch 246/400 - Elapsed Time 1529.624413 - Remaining Time 957.569755
# Epoch 247/400 - Elapsed Time 1535.712781 - Remaining Time 951.271480
# Epoch 248/400 - Elapsed Time 1541.752634 - Remaining Time 944.945163
# Epoch 249/400 - Elapsed Time 1547.753042 - Remaining Time 938.597226
# Epoch 250/400 - Elapsed Time 1553.680664 - Remaining Time 932.208398
# Epoch 251/400 - Elapsed Time 1559.501527 - Remaining Time 925.759871
# Epoch 252/400 - Elapsed Time 1565.600765 - Remaining Time 919.479814
# Epoch 253/400 - Elapsed Time 1571.698739 - Remaining Time 913.200453
# Epoch 254/400 - Elapsed Time 1578.072932 - Remaining Time 907.081292
# Epoch 255/400 - Elapsed Time 1584.732727 - Remaining Time 901.122531
# Epoch 256/400 - Elapsed Time 1590.757255 - Remaining Time 894.800956
# Epoch 257/400 - Elapsed Time 1596.522420 - Remaining Time 888.337378
# Epoch 258/400 - Elapsed Time 1602.459523 - Remaining Time 881.973846
# Epoch 259/400 - Elapsed Time 1608.372844 - Remaining Time 875.600660
# Epoch 260/400 - Elapsed Time 1614.323193 - Remaining Time 869.250950
# Epoch 261/400 - Elapsed Time 1620.348186 - Remaining Time 862.944053
# Epoch 262/400 - Elapsed Time 1626.186201 - Remaining Time 856.540823
# Epoch 263/400 - Elapsed Time 1632.245223 - Remaining Time 850.257017
# Epoch 264/400 - Elapsed Time 1638.093533 - Remaining Time 843.866365
# Epoch 265/400 - Elapsed Time 1647.250933 - Remaining Time 839.165570
# Epoch 266/400 - Elapsed Time 1653.252912 - Remaining Time 832.841692
# Epoch 267/400 - Elapsed Time 1659.501124 - Remaining Time 826.642882
# Epoch 268/400 - Elapsed Time 1665.846189 - Remaining Time 820.491406
# Epoch 269/400 - Elapsed Time 1671.854123 - Remaining Time 814.174313
# Epoch 270/400 - Elapsed Time 1677.868515 - Remaining Time 807.862618
# Epoch 271/400 - Elapsed Time 1683.818987 - Remaining Time 801.522691
# Epoch 272/400 - Elapsed Time 1689.776415 - Remaining Time 795.188901
# Epoch 273/400 - Elapsed Time 1695.794409 - Remaining Time 788.886044
# Epoch 274/400 - Elapsed Time 1701.937646 - Remaining Time 782.642859
# Epoch 275/400 - Elapsed Time 1708.140796 - Remaining Time 776.427635
# Epoch 276/400 - Elapsed Time 1714.082698 - Remaining Time 770.095125
# Epoch 277/400 - Elapsed Time 1720.039774 - Remaining Time 763.772174
# Epoch 278/400 - Elapsed Time 1726.041886 - Remaining Time 757.471619
# Epoch 279/400 - Elapsed Time 1731.927207 - Remaining Time 751.122552
# Epoch 280/400 - Elapsed Time 1738.021943 - Remaining Time 744.866547
# Epoch 281/400 - Elapsed Time 1744.574924 - Remaining Time 738.805751
# Epoch 282/400 - Elapsed Time 1750.863211 - Remaining Time 732.630705
# Epoch 283/400 - Elapsed Time 1756.634378 - Remaining Time 726.241068
# Epoch 284/400 - Elapsed Time 1762.500747 - Remaining Time 719.894671
# Epoch 285/400 - Elapsed Time 1768.428135 - Remaining Time 713.576265
# Epoch 286/400 - Elapsed Time 1774.857882 - Remaining Time 707.460834
# Epoch 287/400 - Elapsed Time 1780.865921 - Remaining Time 701.177175
# Epoch 288/400 - Elapsed Time 1786.799560 - Remaining Time 694.866496
# Epoch 289/400 - Elapsed Time 1792.793002 - Remaining Time 688.581395
# Epoch 290/400 - Elapsed Time 1799.213317 - Remaining Time 682.460224
# Epoch 291/400 - Elapsed Time 1805.151103 - Remaining Time 676.156255
# Epoch 292/400 - Elapsed Time 1811.117923 - Remaining Time 669.865533
# Epoch 293/400 - Elapsed Time 1816.966079 - Remaining Time 663.533688
# Epoch 294/400 - Elapsed Time 1823.622895 - Remaining Time 657.496690
# Epoch 295/400 - Elapsed Time 1830.185875 - Remaining Time 651.422091
# Epoch 296/400 - Elapsed Time 1837.011375 - Remaining Time 645.436429
# Epoch 297/400 - Elapsed Time 1842.984171 - Remaining Time 639.149393
# Epoch 298/400 - Elapsed Time 1849.019530 - Remaining Time 632.885879
# Epoch 299/400 - Elapsed Time 1854.932313 - Remaining Time 626.582487
# Epoch 300/400 - Elapsed Time 1860.827200 - Remaining Time 620.275733
# Epoch 301/400 - Elapsed Time 1866.558052 - Remaining Time 613.917765
# Epoch 302/400 - Elapsed Time 1872.650273 - Remaining Time 607.681214
# Epoch 303/400 - Elapsed Time 1878.710172 - Remaining Time 601.435270
# Epoch 304/400 - Elapsed Time 1884.598629 - Remaining Time 595.136409
# Epoch 305/400 - Elapsed Time 1890.597323 - Remaining Time 588.874576
# Epoch 306/400 - Elapsed Time 1896.662376 - Remaining Time 582.634847
# Epoch 307/400 - Elapsed Time 1903.680118 - Remaining Time 576.684856
# Epoch 308/400 - Elapsed Time 1909.956068 - Remaining Time 570.506358
# Epoch 309/400 - Elapsed Time 1915.722133 - Remaining Time 564.177068
# Epoch 310/400 - Elapsed Time 1921.697941 - Remaining Time 557.912305
# Epoch 311/400 - Elapsed Time 1927.539992 - Remaining Time 551.611123
# Epoch 312/400 - Elapsed Time 1933.673670 - Remaining Time 545.395138
# Epoch 313/400 - Elapsed Time 1939.508331 - Remaining Time 539.096565
# Epoch 314/400 - Elapsed Time 1945.313734 - Remaining Time 532.792934
# Epoch 315/400 - Elapsed Time 1951.321018 - Remaining Time 526.546941
# Epoch 316/400 - Elapsed Time 1957.267731 - Remaining Time 520.286359
# Epoch 317/400 - Elapsed Time 1965.829186 - Remaining Time 514.712374
# Epoch 318/400 - Elapsed Time 1971.657168 - Remaining Time 508.414742
# Epoch 319/400 - Elapsed Time 1977.555720 - Remaining Time 502.137973
# Epoch 320/400 - Elapsed Time 1984.295369 - Remaining Time 496.073842
# Epoch 321/400 - Elapsed Time 1990.614359 - Remaining Time 489.901976
# Epoch 322/400 - Elapsed Time 1996.784751 - Remaining Time 483.693201
# Epoch 323/400 - Elapsed Time 2002.758542 - Remaining Time 477.437795
# Epoch 324/400 - Elapsed Time 2008.638363 - Remaining Time 471.162085
# Epoch 325/400 - Elapsed Time 2014.845372 - Remaining Time 464.964317
# Epoch 326/400 - Elapsed Time 2020.921725 - Remaining Time 458.736833
# Epoch 327/400 - Elapsed Time 2026.833478 - Remaining Time 452.473529
# Epoch 328/400 - Elapsed Time 2033.206377 - Remaining Time 446.313595
# Epoch 329/400 - Elapsed Time 2039.200350 - Remaining Time 440.070592
# Epoch 330/400 - Elapsed Time 2045.093896 - Remaining Time 433.807796
# Epoch 331/400 - Elapsed Time 2051.155150 - Remaining Time 427.582191
# Epoch 332/400 - Elapsed Time 2057.235899 - Remaining Time 421.361570
# Epoch 333/400 - Elapsed Time 2063.706609 - Remaining Time 415.220249
# Epoch 334/400 - Elapsed Time 2070.059847 - Remaining Time 409.053742
# Epoch 335/400 - Elapsed Time 2076.043541 - Remaining Time 402.814418
# Epoch 336/400 - Elapsed Time 2081.858862 - Remaining Time 396.544545
# Epoch 337/400 - Elapsed Time 2087.940856 - Remaining Time 390.327222
# Epoch 338/400 - Elapsed Time 2094.162377 - Remaining Time 384.136294
# Epoch 339/400 - Elapsed Time 2100.319759 - Remaining Time 377.933644
# Epoch 340/400 - Elapsed Time 2106.777345 - Remaining Time 371.784237
# Epoch 341/400 - Elapsed Time 2112.562113 - Remaining Time 365.516612
# Epoch 342/400 - Elapsed Time 2118.834738 - Remaining Time 359.334546
# Epoch 343/400 - Elapsed Time 2124.684783 - Remaining Time 353.081728
# Epoch 344/400 - Elapsed Time 2130.646128 - Remaining Time 346.849370
# Epoch 345/400 - Elapsed Time 2136.560836 - Remaining Time 340.611148
# Epoch 346/400 - Elapsed Time 2143.120025 - Remaining Time 334.475380
# Epoch 347/400 - Elapsed Time 2149.659505 - Remaining Time 328.334161
# Epoch 348/400 - Elapsed Time 2155.508547 - Remaining Time 322.087484
# Epoch 349/400 - Elapsed Time 2161.832034 - Remaining Time 315.912418
# Epoch 350/400 - Elapsed Time 2167.674122 - Remaining Time 309.667732
# Epoch 351/400 - Elapsed Time 2173.444848 - Remaining Time 303.415378
# Epoch 352/400 - Elapsed Time 2179.475453 - Remaining Time 297.201198
# Epoch 353/400 - Elapsed Time 2185.647502 - Remaining Time 291.006891
# Epoch 354/400 - Elapsed Time 2191.560182 - Remaining Time 284.779007
# Epoch 355/400 - Elapsed Time 2197.637149 - Remaining Time 278.573723
# Epoch 356/400 - Elapsed Time 2203.634428 - Remaining Time 272.359311
# Epoch 357/400 - Elapsed Time 2209.701101 - Remaining Time 266.154474
# Epoch 358/400 - Elapsed Time 2215.595345 - Remaining Time 259.930180
# Epoch 359/400 - Elapsed Time 2221.968028 - Remaining Time 253.762365
# Epoch 360/400 - Elapsed Time 2228.631137 - Remaining Time 247.625682
# Epoch 361/400 - Elapsed Time 2234.632150 - Remaining Time 241.414554
# Epoch 362/400 - Elapsed Time 2240.709133 - Remaining Time 235.212561
# Epoch 363/400 - Elapsed Time 2246.691643 - Remaining Time 229.001628
# Epoch 364/400 - Elapsed Time 2252.695340 - Remaining Time 222.794045
# Epoch 365/400 - Elapsed Time 2258.472767 - Remaining Time 216.565882
# Epoch 366/400 - Elapsed Time 2264.315840 - Remaining Time 210.346280
# Epoch 367/400 - Elapsed Time 2270.290030 - Remaining Time 204.140520
# Epoch 368/400 - Elapsed Time 2276.403117 - Remaining Time 197.948097
# Epoch 369/400 - Elapsed Time 2282.438773 - Remaining Time 191.749599
# Epoch 370/400 - Elapsed Time 2290.950347 - Remaining Time 185.752731
# Epoch 371/400 - Elapsed Time 2296.965554 - Remaining Time 179.547173
# Epoch 372/400 - Elapsed Time 2303.093472 - Remaining Time 173.351122
# Epoch 373/400 - Elapsed Time 2309.567166 - Remaining Time 167.180465
# Epoch 374/400 - Elapsed Time 2315.709185 - Remaining Time 160.985131
# Epoch 375/400 - Elapsed Time 2321.710560 - Remaining Time 154.780704
# Epoch 376/400 - Elapsed Time 2327.418364 - Remaining Time 148.558619
# Epoch 377/400 - Elapsed Time 2333.479139 - Remaining Time 142.360796
# Epoch 378/400 - Elapsed Time 2339.336533 - Remaining Time 136.151862
# Epoch 379/400 - Elapsed Time 2345.404222 - Remaining Time 129.956434
# Epoch 380/400 - Elapsed Time 2351.618292 - Remaining Time 123.769384
# Epoch 381/400 - Elapsed Time 2357.453730 - Remaining Time 117.563309
# Epoch 382/400 - Elapsed Time 2363.204442 - Remaining Time 111.355183
# Epoch 383/400 - Elapsed Time 2369.216027 - Remaining Time 105.161025
# Epoch 384/400 - Elapsed Time 2375.325320 - Remaining Time 98.971888
# Epoch 385/400 - Elapsed Time 2381.090435 - Remaining Time 92.769757
# Epoch 386/400 - Elapsed Time 2387.492472 - Remaining Time 86.592991
# Epoch 387/400 - Elapsed Time 2393.724043 - Remaining Time 80.409335
# Epoch 388/400 - Elapsed Time 2399.572522 - Remaining Time 74.213583
# Epoch 389/400 - Elapsed Time 2405.910159 - Remaining Time 68.033449
# Epoch 390/400 - Elapsed Time 2411.965698 - Remaining Time 61.845274
# Epoch 391/400 - Elapsed Time 2418.107752 - Remaining Time 55.659769
# Epoch 392/400 - Elapsed Time 2423.967685 - Remaining Time 49.468728
# Epoch 393/400 - Elapsed Time 2429.781101 - Remaining Time 43.278544
# Epoch 394/400 - Elapsed Time 2435.744033 - Remaining Time 37.092549
# Epoch 395/400 - Elapsed Time 2441.665485 - Remaining Time 30.907158
# Epoch 396/400 - Elapsed Time 2447.586795 - Remaining Time 24.723099
# Epoch 397/400 - Elapsed Time 2454.009193 - Remaining Time 18.544150
# Epoch 398/400 - Elapsed Time 2460.224983 - Remaining Time 12.362940
# Epoch 399/400 - Elapsed Time 2466.880066 - Remaining Time 6.182657
# Epoch 400/400 - Elapsed Time 2473.220271 - Remaining Time 0.000000

# %% [markdown]
# The next block will run prediction on the test set and save the output detections

# %%
from __future__ import division
from __future__ import print_function

import numpy as np
import torch
from torch.utils.data import DataLoader
from torchvision import transforms

from hourglass import hg

from dataset import Dataset
from dataset import CropAndPad, LocsToHeatmaps, ToTensor, Normalize
from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = hg(num_stacks=1, num_blocks=1, num_classes=10).to(device)
checkpoint = torch.load('/content/gdrive/My Drive/cis580-2019-hw6/model_checkpoint.pt')
model.load_state_dict(checkpoint['model'])
transform_list = [CropAndPad(out_size=(256, 256))]
transform_list.append(LocsToHeatmaps(out_size=(64,64)))
transform_list.append(ToTensor())
transform_list.append(Normalize())
test_ds = Dataset(is_train=False, transform=transforms.Compose(transform_list))
data_loader = DataLoader(test_ds, batch_size=1, pin_memory=True, shuffle=False)
predicted_heatmaps = np.zeros((len(test_ds), 10, 64, 64))
for i, batch in enumerate(tqdm(data_loader)):
    model.eval()
    images = batch['image'].to(device)
    with torch.no_grad():
        pred_heatmap_list = model(images)
    pred_heatmaps = pred_heatmap_list[-1]
    predicted_heatmaps[i,:,:,:] = pred_heatmaps[0,:,:,:].cpu().numpy()
np.save('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy', predicted_heatmaps)
# Out:
# 100%|██████████| 27/27 [00:00<00:00, 31.32it/s]

# %% [markdown]
# Import the external and given functions for step 2

# %%
import numpy as np
import torch
import torch.nn as nn
import cv2
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import os
from os.path import join
from utils import plot_mesh

"""
Convert axis-angle representation to a 3x3 rotation matrix
"""
class Rodrigues(torch.autograd.Function):
    @staticmethod
    def forward(self, inp):
        pose = inp.detach().cpu().numpy()
        rotm, part_jacob = cv2.Rodrigues(pose)
        self.jacob = torch.Tensor(np.transpose(part_jacob)).contiguous()
        rotation_matrix = torch.Tensor(rotm.ravel())
        return rotation_matrix.view(3,3)

    @staticmethod
    def backward(self, grad_output):
        grad_output = grad_output.view(1,-1)
        grad_input = torch.mm(grad_output, self.jacob)
        grad_input = grad_input.view(-1)
        return grad_input
"""
This is the function you should call to convert from axis-angle to a rotation matrix
Example usage:
    aa = torch.zeros(3)
    R = rodrigues(aa)
"""
rodrigues = Rodrigues.apply

# %% [markdown]
# Step 2) Implement pose_optimization and heatmaps_to_locs as specified by the accompanying PDF

# %%
"""
YOU NEED TO IMPLEMENT THIS
Input: image, mesh vertices, mesh faces, detected 2d keypoints, keypoint confidences, 3D keypoint coordinates in the canonical position, intrinsic camera matrix
Output: R, t
"""
def pose_optimization(img, vertices, faces, keypoints_2d, conf, keypoints_3d, K):
    # Send variables to GPU
    device = keypoints_2d.device
    keypoints_3d = keypoints_3d.to(device)
    K = K.to(device)
    r = torch.rand(3, requires_grad=True, device=device) # rotation in axis-angle representation
    t = torch.rand(3 ,requires_grad=True, device=device)
    d=torch.diag(conf.sqrt())
    """d = conf.sqrt()[:, None]"""
    # 2D keypoints in normalized coordinates
    norm_keypoints_2d = torch.matmul(K.inverse(), torch.cat((keypoints_2d, torch.ones(keypoints_2d.shape[0],1, device=device)), dim=-1).t()).t()[:,:-1]
    # set up optimizer
    optimizer = torch.optim.Adam([r,t], lr=1e-2)
    # converge check
    converged = False
    rel_tol = 1e-5
    loss_old = 100
    while not converged:
      # convert axis-angle to rotation matrix
      R = rodrigues(r)
      # 1) Compute projected keypoints based on current estimate of R and t
      # 3 x k
      # TODO: is t in 
      proj_keypoints=torch.zeros([10,2])
      P=torch.mm(keypoints_3d,R.t())
      P=P+t.unsqueeze(dim=0)
      proj_keypoints[:,0]=P[:,0]/P[:,2]
      proj_keypoints[:,1]=P[:,1]/P[:,2]
      # 2) Compute error (based on distance between projected keypoints and detected keypoints)
      loss=torch.norm(torch.mm((norm_keypoints_2d-proj_keypoints).t(),d),p='fro')
      # 3) Update based on error
      optimizer.zero_grad()
      loss.backward()
      # 4) Check for convergence
      optimizer.step()
      if abs(loss_old-loss)<=rel_tol:
        converged=True
        
      loss_old=loss

    R = rodrigues(r)
    plt.figure()
    plot_mesh(img, vertices, faces, R.detach().cpu().numpy(), t.detach().cpu().numpy()[:,None], K.detach().cpu().numpy())
    pk = torch.matmul(K, torch.cat((proj_keypoints, torch.ones(proj_keypoints.shape[0], 1, device=device)), dim=-1).t()).t()
    pk = pk.detach().cpu().numpy()
    plt.scatter(pk[:,0], pk[:,1], color='r')
    plt.show()
    return rodrigues(r)[0].detach(), t.detach()

"""
YOU NEED TO IMPLEMENT THIS
Convert heatmaps to 2D locations
Input: Nx10x64x64 keypoint heatmaps
Output: Nx10x3 keypoint locations and detection confidence (magnitude of the highest activation)
"""
def heatmaps_to_locs(heatmaps):
    N = len(heatmaps)
    output = torch.zeros(N,10,3)
    for i in range(N):
      for j in range(10):
        
        max = -100
        x= -1
        y= -1
        for x1 in range(64):
          for y1 in range(64):
            
            if heatmaps[i,j,x1,y1]>max:
              max = heatmaps[i,j,x1,y1]
              x = x1
              y = y1
        
        output[i,j,0] = y
        output[i,j,1] = x
        output[i,j,2] = max
    
    return output

# %% [markdown]
# The next block will start the pose optimization process. Be sure to run the above block first every time you want to test changes to the code.

# %%
data = np.load('data/misc_data.npz')
K = torch.from_numpy(data['K']).float()
S = torch.from_numpy(np.load('data/kpt.npy'))
vertices = data['vertices']
faces = data['faces']

dataset = np.load('data/valid_data.npz')
imgnames = dataset['imgname']
scales = torch.from_numpy(dataset['scale']).float()[:,None]
centers = torch.from_numpy(dataset['center']).float()
# detections.npy contains the detections saved after training your model and running predict.py
heatmaps = torch.from_numpy(np.load('/content/gdrive/My Drive/cis580-2019-hw6/detections.npy'))

keypoint_locs = heatmaps_to_locs(heatmaps)

# Compute detected 2D keypoint locations in the original image
ul_corner = centers - scales * 100
keypoint_locs[:,:,:-1] *= scales[:,:,None]*200 / 64
keypoint_locs[:,:,:-1] += ul_corner[:,None,:]

images = np.load('data/images.npz')

os.makedirs('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization', exist_ok=True)
for i in range(len(heatmaps)):
    img_name = imgnames[i].decode('utf-8')
    print("Processing ", img_name)
    img = images[img_name]
    pose_optimization(img, vertices, faces, keypoint_locs[i,:,:-1], keypoint_locs[i,:,-1], S, K)
    plt.savefig('/content/gdrive/My Drive/cis580-2019-hw6/pose_optimization/%s' % img_name, dpi=300)
    plt.close('all')
# Out:
# Processing  train_148.jpg
# Processing  train_160.jpg
# Processing  train_80.jpg
# Processing  train_181.jpg
# Processing  train_176.jpg
# Processing  train_2.jpg
# Processing  train_155.jpg
# Processing  train_136.jpg
# Processing  train_4.jpg
# Processing  train_18.jpg
# Processing  train_106.jpg
# Processing  train_90.jpg
# Processing  train_25.jpg
# Processing  train_116.jpg
# Processing  train_190.jpg
# Processing  train_177.jpg
# Processing  train_52.jpg
# Processing  train_191.jpg
# Processing  train_13.jpg
# Processing  train_9.jpg
# Processing  train_81.jpg
# Processing  train_21.jpg
# Processing  train_72.jpg
# Processing  train_144.jpg
# Processing  train_10.jpg
# Processing  train_12.jpg
# Processing  train_140.jpg
